# %%
# 네이버 검색 API 예제 - 뉴스 검색
import os
import sys
import urllib.request

# 발급받은 naver API id / secret
client_id = "***************"
client_secret = "*********"

encText = urllib.parse.quote("손흥민")  # 검색어
url = "https://openapi.naver.com/v1/search/news?query=" + encText + "&display=100" # JSON 결과
# url = "https://openapi.naver.com/v1/search/news.xml?query=" + encText # XML 결과

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    body = response_body.decode('utf-8')
    print(body)
else:
    print("Error Code:" + rescode)

#body 나누기
list1 = body.split('\n\t\t{\n\t\t\t')
# print(list1)
# Out:
# {
# 	"lastBuildDate":"Thu, 12 Dec 2024 00:17:54 +0900",
# 	"total":683955,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"양민혁 16일 영국행…최고수준 이적료 평가",
# 			"originallink":"http:\/\/www.kado.net\/news\/articleView.html?idxno=1282188",
# 			"link":"https:\/\/m.sports.naver.com\/kfootball\/article\/654\/0000096748",
# 			"description":"양민혁은 한국 축구 간판 <b>손흥민<\/b>(춘천출신)이 뛰는 토트넘의 선택을 받아 이달 중순 잉글랜드 프리미어리그(EPL)로 이적한다. #양민혁 #이적료 #최고수준 #토트넘 #K리그",
# 			"pubDate":"Thu, 12 Dec 2024 00:06:00 +0900"
# 		},
# 		{
# 			"title":"로메로의 폭탄발언 &quot;토트넘, 맨시티·리버풀·첼시 본받아야→구단 수뇌...",
# 			"originallink":"https:\/\/www.spotvnews.co.kr\/news\/articleView.html?idxno=718994",
# 			"link":"https:\/\/m.sports.naver.com\/wfootball\/article\/477\/0000525393",
# 			"description":"엔제 포스테코글루 토트넘 감독은 경질설에 시달리고 있다. 주장이자 에이스인 <b>손흥민<\/b> 이적설도 나돈다. 뒤숭숭한 분위기 속에 로메로의 일침이 토트넘에 어떤 변화를 일으킬지 주목된다.",
# 			"pubDate":"Wed, 11 Dec 2024 23:55:00 +0900"
# 		},
# 		{
# 			"title":"'SON 1+2년 종신계약? 말장난 하나' 토트넘의 침묵+에이전트의 희망회로...",
# 			"originallink":"https:\/\/sports.chosun.com\/football\/2024-12-11\/202412110100073980012308",
# 			"link":"https:\/\/m.sports.naver.com\/wfootball\/article\/076\/0004225272",
# 			"description":"' 토트넘 홋스퍼 '캡틴' <b>손흥민<\/b>(32)의 거취를 둘러싸고 영국 현지에서 계속 새 소식이 흘러나오고 있다. '1년 연장'에서 '맨체스터 유나이티드 영입설', '바르셀로나 영입설', '레알 마드리드 영입설''<b>손흥민<\/b>의 이적 선제안설... ",
# 			"pubDate":"Wed, 11 Dec 2024 23:40:00 +0900"
# 		},
# 		{
# 			"title":"올해 한국 구글 검색어 2위 '계엄령'",
# 			"originallink":"https:\/\/zdnet.co.kr\/view\/?no=20241211231057",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/092\/0002356113?sid=105",
# 			"description":"<b>손흥민<\/b> 선수가 속해 있는 ‘토트넘 홋스퍼 FC 매치’가 1위, ‘대한민국 축구 국가대표팀 매치’가 2위, UEFA 유럽 축구 선수권 대회 (‘유로 2024’)가 3위를 차지했다. 또한, 기아와 삼성의 한국시리즈인 ‘삼성 대 기아... ",
# 			"pubDate":"Wed, 11 Dec 2024 23:17:00 +0900"
# 		},
# 		{
# 			"title":"<b>손흥민<\/b> 전설 대우는 없다?…토트넘, 주급 인상 없이 '1+2년 연장 전망'",
# 			"originallink":"https:\/\/www.fourfourtwo.co.kr\/news\/articleView.html?idxno=64398",
# 			"link":"https:\/\/m.sports.naver.com\/wfootball\/article\/411\/0000056262",
# 			"description":"토트넘 홋스퍼와 <b>손흥민<\/b>이 재계약 협상을 진행 중이라는 소식이 전해졌다. 그러나 영국 현지에서는 <b>손흥민<\/b>의 주급 인상은 없을 것이라 전망하고 있다. 토트넘 소식을 전하는 '스퍼스웹'은 10일(한국시간) &quot;<b>손흥민<\/b> 에이전트... ",
# 			"pubDate":"Wed, 11 Dec 2024 23:15:00 +0900"
# 		},
# 		{
# 			"title":"[속보] 김민재, '1500억' 첼시 역대급 먹튀와 한솥밥 먹나…단장·감독,...",
# 			"originallink":"https:\/\/www.sportalkorea.com\/news\/view.php?gisa_uniq=2024121122303933&section_code=2070&cp=se&sp=A",
# 			"link":"https:\/\/m.sports.naver.com\/wfootball\/article\/139\/0002215350",
# 			"description":"우리나라에서 <b>손흥민<\/b>(토트넘 핫스퍼)의 거취가 큰 주목을 받듯 우크라이나 축구계를 뜨겁게 달군 소식은 무드리크의 차기 행선지였다. 현지 매체에 따르면 무드리크는 공격진 보강을 꾀하는 뮌헨의 관심을 받고 있다.... ",
# 			"pubDate":"Wed, 11 Dec 2024 22:55:00 +0900"
# 		},
# 		{
# 			"title":"‘말로만 토트넘 레전드 대우’ <b>손흥민<\/b>, 1+2년 재계약해도 주급상승 전...",
# 			"originallink":"http:\/\/www.osen.co.kr\/article\/G1112472298",
# 			"link":"https:\/\/m.sports.naver.com\/wfootball\/article\/109\/0005210856",
# 			"description":"<b>손흥민<\/b>(32, 토트넘)이 영원한 토트넘 레전드로 남을까. 토트넘 팬사이트 ‘스퍼스웹’은 “토트넘이 <b>손흥민<\/b>과 1년 연장계약을 발동할 것이다. 시간을 번 토트넘이 <b>손흥민<\/b>과 장기 연장계약에 합의할 것”이라고... ",
# 			"pubDate":"Wed, 11 Dec 2024 22:28:00 +0900"
# 		},
# 		{
# 			"title":"<b>손흥민<\/b> 토트넘 종신? 1+2년 재계약+최고 주급 전망...36살까지 토트넘서...",
# 			"originallink":"https:\/\/www.interfootball.co.kr\/news\/articleView.html?idxno=645768",
# 			"link":"https:\/\/m.sports.naver.com\/wfootball\/article\/413\/0000188279",
# 			"description":"<b>손흥민<\/b>이 토트넘 훗스퍼에서 은퇴할까. 최근 <b>손흥민<\/b>의 거취를 둘러싸고 색다른 주장이 나왔다. 갈라타사라이, 바르셀로나, 맨체스터 유나이티드 등 여러 이적설이 계속됐는데, <b>손흥민<\/b>이 2028년까지 토트넘에 남을... ",
# 			"pubDate":"Wed, 11 Dec 2024 22:16:00 +0900"
# 		},
# 		{
# 			"title":"토트넘 드디어 정신 차렸다! '레전드' <b>손흥민<\/b>과 재계약 추진...&quot;이적설 ...",
# 			"originallink":"https:\/\/mydaily.co.kr\/page\/view\/2024121115272466223",
# 			"link":"https:\/\/m.sports.naver.com\/wfootball\/article\/117\/0003895581",
# 			"description":"구단 레전드 <b>손흥민<\/b>과 재계약을 추진할 것으로 보인다. 토트넘 소식을 전하는 '스퍼스웹'은 9일(이하 한국시각) &quot;<b>손흥민<\/b>의 현재 계약은 이번 시즌을 끝으로 만료되지만 1년 연장 옵션을 발동해 계약을 연장할 예정이며... ",
# 			"pubDate":"Wed, 11 Dec 2024 22:16:00 +0900"
# 		},
# 		{
# 			"title":"이적사가 종료? ‘충격 대반전’ <b>손흥민<\/b>, 토트넘 레전드로 남는다…주급...",
# 			"originallink":"https:\/\/www.mk.co.kr\/article\/11191797",
# 			"link":"https:\/\/m.sports.naver.com\/wfootball\/article\/410\/0001040950",
# 			"description":"쏠렸던 <b>손흥민<\/b>, 이제는 토트넘의 레전드로 남을 예정이다. 현지에서는 재계약 가능성을 시사했다. 토트넘 소식을 전하는 ‘스퍼스 웹’은 10일(한국시간) “퇴근 토트넘이 <b>손흥민<\/b>과의 1년 계약 연장 옵션에 동의했다는... ",
# 			"pubDate":"Wed, 11 Dec 2024 21:34:00 +0900"
# 		}
# 	]
# }

# %%
#제목, 링크 뽑기
import re
titles = []
links = []
for i in list1:
    title = re.findall('"title":"(.*?)",\n\t\t\t"originallink"',i)
    link = re.findall('"link":"(.*?)",\n\t\t\t"description"',i)
    titles.append(title)
    links.append(link)

titles = [r for i in titles for r in i]
links = [r for i in links for r in i]

"""
print('<<제목 모음>>')
print(titles)
print('총 제목 수: ',len(titles),'개')  #제목 개수 확인
print('\n<<링크 모음>>')
print(links)
print('총 링크 수: ',len(links),'개')  #링크 개수 확인
"""

# 링크 다듬기 (필요없는 부분 제거 및 수정)
news_links = []
for i in links:
    a = i.replace('\\','')
    b = a.replace('?Redirect=Log&logNo=','/')
    news_links.append(b)

print(news_links)
print('생성된 링크 갯수:',len(news_links),'개')
# Out:
# ['https://m.sports.naver.com/wfootball/article/477/0000525393', 'https://m.sports.naver.com/wfootball/article/076/0004225272', 'https://n.news.naver.com/mnews/article/092/0002356113?sid=105', 'https://m.sports.naver.com/wfootball/article/411/0000056262', 'https://m.sports.naver.com/wfootball/article/139/0002215350', 'https://m.sports.naver.com/wfootball/article/109/0005210856', 'https://m.sports.naver.com/wfootball/article/413/0000188279', 'https://m.sports.naver.com/wfootball/article/117/0003895581', 'https://m.sports.naver.com/wfootball/article/410/0001040950', 'https://m.sports.naver.com/wfootball/article/076/0004225251', 'https://m.sports.naver.com/wfootball/article/139/0002215346', 'https://m.sports.naver.com/wfootball/article/076/0004225245', 'https://m.sports.naver.com/wfootball/article/117